# %%
pip install ipywidgets langchain langchain-community langchain-core langchainhub tiktoken chromadb pysqlite3-binary sentence-transformers pypdf deepsparse-nightly[llm]
# Out:
# Requirement already satisfied: ipywidgets in /opt/app-root/lib/python3.9/site-packages (8.1.1)
# Requirement already satisfied: langchain in /opt/app-root/lib/python3.9/site-packages (0.1.13)
# Requirement already satisfied: langchain-community in /opt/app-root/lib/python3.9/site-packages (0.0.29)
# Requirement already satisfied: langchain-core in /opt/app-root/lib/python3.9/site-packages (0.1.36)
# Requirement already satisfied: langchainhub in /opt/app-root/lib/python3.9/site-packages (0.1.15)
# Requirement already satisfied: tiktoken in /opt/app-root/lib/python3.9/site-packages (0.6.0)
# Requirement already satisfied: chromadb in /opt/app-root/lib/python3.9/site-packages (0.4.24)
# Requirement already satisfied: pysqlite3-binary in /opt/app-root/lib/python3.9/site-packages (0.5.2.post3)
# Requirement already satisfied: sentence-transformers in /opt/app-root/lib/python3.9/site-packages (2.6.1)
# Requirement already satisfied: pypdf in /opt/app-root/lib/python3.9/site-packages (4.1.0)
# Collecting deepsparse-nightly[llm]
#   Downloading deepsparse_nightly-1.7.0.20240304-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 89.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: traitlets>=4.3.1 in /opt/app-root/lib/python3.9/site-packages (from ipywidgets) (5.14.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/app-root/lib/python3.9/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/app-root/lib/python3.9/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: ipython>=6.1.0 in /opt/app-root/lib/python3.9/site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/app-root/lib/python3.9/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/app-root/lib/python3.9/site-packages (from langchain) (0.1.38)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/app-root/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: numpy<2,>=1 in /opt/app-root/lib/python3.9/site-packages (from langchain) (1.24.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/app-root/lib/python3.9/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: PyYAML>=5.3 in /opt/app-root/lib/python3.9/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/app-root/lib/python3.9/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/app-root/lib/python3.9/site-packages (from langchain) (1.33)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/app-root/lib/python3.9/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: requests<3,>=2 in /opt/app-root/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /opt/app-root/lib/python3.9/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: pydantic<3,>=1 in /opt/app-root/lib/python3.9/site-packages (from langchain) (1.10.14)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/app-root/lib/python3.9/site-packages (from langchain) (2.0.29)
# Requirement already satisfied: packaging<24.0,>=23.2 in /opt/app-root/lib/python3.9/site-packages (from langchain-core) (23.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /opt/app-root/lib/python3.9/site-packages (from langchainhub) (2.31.0.20240311)
# Requirement already satisfied: regex>=2022.1.18 in /opt/app-root/lib/python3.9/site-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: overrides>=7.3.1 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: importlib-resources in /opt/app-root/lib/python3.9/site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (4.9.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (0.110.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (1.17.1)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (0.29.0)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (4.66.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (0.45b0)
# Requirement already satisfied: build>=1.0.3 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: posthog>=2.4.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (3.4.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (3.10.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (1.24.0)
# Requirement already satisfied: pypika>=0.48.9 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (1.60.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/app-root/lib/python3.9/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /opt/app-root/lib/python3.9/site-packages (from sentence-transformers) (4.39.2)
# Requirement already satisfied: scipy in /opt/app-root/lib/python3.9/site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: Pillow in /opt/app-root/lib/python3.9/site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/app-root/lib/python3.9/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/app-root/lib/python3.9/site-packages (from sentence-transformers) (0.22.2)
# Requirement already satisfied: scikit-learn in /opt/app-root/lib/python3.9/site-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: click!=8.0.0,>=7.1.2 in /opt/app-root/lib/python3.9/site-packages (from deepsparse-nightly[llm]) (8.1.7)
# Collecting sparsezoo-nightly~=1.7.0
#   Downloading sparsezoo_nightly-1.7.0.20240304-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.8/177.8 kB 200.4 MB/s eta 0:00:00
# Collecting onnx<1.15.0,>=1.5.0
#   Downloading onnx-1.14.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 92.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: protobuf>=3.12.2 in /opt/app-root/lib/python3.9/site-packages (from deepsparse-nightly[llm]) (3.20.2)
# Collecting datasets<2.16
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 147.1 MB/s eta 0:00:00
# Collecting accelerate<0.26
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 218.6 MB/s eta 0:00:00
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 133.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.32.0
#   Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 76.3 MB/s eta 0:00:0000:0100:01
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 166.8 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /opt/app-root/lib/python3.9/site-packages (from accelerate<0.26->deepsparse-nightly[llm]) (0.4.2)
# Requirement already satisfied: psutil in /opt/app-root/lib/python3.9/site-packages (from accelerate<0.26->deepsparse-nightly[llm]) (5.9.8)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/app-root/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in /opt/app-root/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/app-root/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/app-root/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/app-root/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: importlib-metadata>=4.6 in /opt/app-root/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (7.0.0)
# Requirement already satisfied: pyproject_hooks in /opt/app-root/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/app-root/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/app-root/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/app-root/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Collecting fsspec[http]<=2023.10.0,>=2023.1.0
#   Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 194.6 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.16-py39-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 162.3 MB/s eta 0:00:00
# Collecting dill<0.3.8,>=0.3.0
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 186.8 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/app-root/lib/python3.9/site-packages (from datasets<2.16->deepsparse-nightly[llm]) (15.0.0)
# Collecting xxhash
#   Downloading xxhash-3.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.8/193.8 kB 211.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.9/site-packages (from datasets<2.16->deepsparse-nightly[llm]) (1.5.3)
# Collecting pyarrow-hotfix
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /opt/app-root/lib/python3.9/site-packages (from fastapi>=0.95.2->chromadb) (0.36.3)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/app-root/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: decorator in /opt/app-root/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: exceptiongroup in /opt/app-root/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: stack-data in /opt/app-root/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /opt/app-root/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/app-root/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/app-root/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/app-root/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/app-root/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/app-root/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: requests-oauthlib in /opt/app-root/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: certifi>=14.05.14 in /opt/app-root/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/app-root/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: six>=1.9.0 in /opt/app-root/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/app-root/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/app-root/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/app-root/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: coloredlogs in /opt/app-root/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: sympy in /opt/app-root/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: flatbuffers in /opt/app-root/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: setuptools>=16.0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.1.2)
# Requirement already satisfied: asgiref~=3.0 in /opt/app-root/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in /opt/app-root/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: monotonic>=1.5 in /opt/app-root/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.6)
# Collecting geocoder>=1.38.0
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 194.4 MB/s eta 0:00:00
# Collecting py-machineid>=0.3.0
#   Downloading py_machineid-0.5.1-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (2.19.3)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: triton==2.2.0 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/app-root/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.4.99)
# Requirement already satisfied: h11>=0.8 in /opt/app-root/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/app-root/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/app-root/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in /opt/app-root/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/app-root/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: websockets>=10.4 in /opt/app-root/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: zipp>=3.1.0 in /opt/app-root/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/app-root/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Collecting future
#   Downloading future-1.0.0-py3-none-any.whl (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 135.4 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/app-root/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/app-root/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/app-root/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas->datasets<2.16->deepsparse-nightly[llm]) (2024.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/app-root/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/app-root/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/app-root/lib/python3.9/site-packages (from starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (4.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/app-root/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/app-root/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Collecting multiprocess
#   Downloading multiprocess-0.70.15-py39-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 196.8 MB/s eta 0:00:00
# Requirement already satisfied: asttokens>=2.1.0 in /opt/app-root/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/app-root/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /opt/app-root/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/app-root/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/app-root/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=c4337a25f199beb0642abed8e54d457a1daba7adac1a5745ca4201a5b1f7e177
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pg4d5qgc/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
# Successfully built seqeval
# Installing collected packages: py-machineid, xxhash, ratelim, pyarrow-hotfix, onnx, future, fsspec, dill, responses, multiprocess, geocoder, sparsezoo-nightly, seqeval, transformers, deepsparse-nightly, datasets, accelerate, evaluate
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.15.0
#     Uninstalling onnx-1.15.0:
#       Successfully uninstalled onnx-1.15.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.2.0
#     Uninstalling fsspec-2024.2.0:
#       Successfully uninstalled fsspec-2024.2.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.2
#     Uninstalling transformers-4.39.2:
#       Successfully uninstalled transformers-4.39.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# codeflare-torchx 0.6.0.dev1 requires urllib3<1.27,>=1.21.1, but you have urllib3 2.2.1 which is incompatible.
# codeflare-sdk 0.13.0 requires kubernetes<27,>=25.3.0, but you have kubernetes 29.0.0 which is incompatible.
# Successfully installed accelerate-0.25.0 datasets-2.15.0 deepsparse-nightly-1.7.0.20240304 dill-0.3.7 evaluate-0.4.1 fsspec-2023.10.0 future-1.0.0 geocoder-1.38.1 multiprocess-0.70.15 onnx-1.14.1 py-machineid-0.5.1 pyarrow-hotfix-0.6 ratelim-0.1.6 responses-0.18.0 seqeval-1.2.2 sparsezoo-nightly-1.7.0.20240304 transformers-4.36.2 xxhash-3.4.1
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Set Up The Model
# In this block, we install chromadb and other dependancies.  Chroma requires sqlite3 so that is imported as well.
#
# The LLM that is used is Mistral:Instruct that is hosted by an Ollama container running in OpenShift.
#
# HuggingFace Embeddings are used since they can be run locally and can be configured to take advantage of available GPUs.

# %%
__import__('pysqlite3')
import sys
sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')
import chromadb

import bs4
import os.path
from langchain import hub
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.chat_models import ChatOllama
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pprint import pprint
from deepsparse import TextGeneration

#model = ChatOllama(model="mistral:instruct",
#                   base_url="http://ollama-api-service.ollama-llm.svc.cluster.local:11434",
#                   temperature = 0)
model = TextGeneration(model="zoo:llama2-7b-gsm8k_llama2_pretrain-pruned50_quantized")

from langchain_community.embeddings import HuggingFaceEmbeddings

#embd = HuggingFaceEmbeddings(model_kwargs={'device': 'cuda'})
embd = HuggingFaceEmbeddings(model_kwargs={'device': 'cpu'})
# Out:
# Downloading Chunks for deployment.tar.gz:   0%|          | 0.00/4.58G [00:00<?, ?B/s][Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# Downloading Chunks for deployment.tar.gz:   0%|          | 0.00/4.58G [00:27<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/app-root/lib64/python3.9/site-packages/sparsezoo/utils/download.py:307, in Downloader.run(self, num_threads)
#     306         for future in futures:
# --> 307             future.result()
#     308 is_prev_job_queue_success = True
#
# File /usr/lib64/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib64/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     311 if timeout is None:
# --> 312     waiter.acquire()
#     313     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 23
#      18 from deepsparse import TextGeneration
#      20 #model = ChatOllama(model="mistral:instruct",
#      21 #                   base_url="http://ollama-api-service.ollama-llm.svc.cluster.local:11434",
#      22 #                   temperature = 0)
# ---> 23 model = TextGeneration(model="zoo:llama2-7b-gsm8k_llama2_pretrain-pruned50_quantized")
#      25 from langchain_community.embeddings import HuggingFaceEmbeddings
#      27 #embd = HuggingFaceEmbeddings(model_kwargs={'device': 'cuda'})
#
# File /opt/app-root/lib64/python3.9/site-packages/deepsparse/pipeline.py:714, in text_generation_pipeline(*args, **kwargs)
#     709 """
#     710 :return: text generation pipeline with the given args and
#     711     kwargs passed to Pipeline.create
#     712 """
#     713 kwargs = _check_model_path_arg(*args, **kwargs)
# --> 714 return Pipeline.create("text_generation", **kwargs)
#
# File /opt/app-root/lib64/python3.9/site-packages/deepsparse/pipeline.py:140, in Pipeline.create(cls, task, **kwargs)
#     137 elif model:
#     138     new_kwargs["model_path"] = model
# --> 140 pipeline = Operator.create(task=task, **new_kwargs)
#     141 if not isinstance(pipeline, cls):
#     142     raise RuntimeError(
#     143         "Pipeline was not created for the given task. The "
#     144         "provided task should be registered using the OperatorRegistry"
#     145     )
#
# File /opt/app-root/lib64/python3.9/site-packages/deepsparse/operators/operator.py:137, in Operator.create(cls, task, **kwargs)
#     135 except Exception:
#     136     raise
# --> 137 return operator_constructor(**kwargs)
#
# File /opt/app-root/lib64/python3.9/site-packages/deepsparse/transformers/pipelines/text_generation/pipeline.py:81, in TextGenerationPipeline.__new__(cls, model_path, sequence_length, onnx_model_name, **kwargs)
#      62 def __new__(
#      63     cls,
#      64     model_path: str,
#    (...)
#      67     **kwargs,
#      68 ):
#      69     """
#      70     Dynamically decide which pipeline (with KV Cache support or without)
#      71     to initialize based on the model_path
#    (...)
#      79         model.onnx
#      80     """
# ---> 81     model_path, config, tokenizer = setup_transformers_pipeline(
#      82         model_path=model_path,
#      83         sequence_length=sequence_length,
#      84         onnx_model_name=onnx_model_name,
#      85     )
#      87     if not verify_kv_cache_present(model_path):
#      88         _LOGGER.info(
#      89             "Initializing TextGenerationPipeline without KV Cache support. "
#      90             "Some of the input parameters will be ignored."
#      91         )
#
# File /opt/app-root/lib64/python3.9/site-packages/deepsparse/transformers/helpers.py:66, in setup_transformers_pipeline(model_path, sequence_length, tokenizer_padding_side, onnx_model_name)
#      49 def setup_transformers_pipeline(
#      50     model_path: str,
#      51     sequence_length: int,
#      52     tokenizer_padding_side: str = "left",
#      53     onnx_model_name: Optional[str] = None,
#      54 ) -> Tuple[str, transformers.PretrainedConfig, transformers.PreTrainedTokenizer]:
#      55     """
#      56     A helper function that sets up the model path, config, tokenizer,
#      57     and engine kwargs for a transformers model.
#    (...)
#      64     :return The model path, config, tokenizer
#      65     """
# ---> 66     model_path, config, tokenizer = fetch_onnx_file_path(
#      67         model_path, sequence_length, onnx_model_name
#      68     )
#      70     tokenizer.padding_side = tokenizer_padding_side
#      71     if not tokenizer.pad_token:
#
# File /opt/app-root/lib64/python3.9/site-packages/deepsparse/transformers/helpers.py:95, in fetch_onnx_file_path(model_path, sequence_length, onnx_model_name, task)
#      77 def fetch_onnx_file_path(
#      78     model_path: str,
#      79     sequence_length: int,
#      80     onnx_model_name: Optional[str] = None,
#      81     task: Optional[str] = None,
#      82 ) -> Tuple[str, transformers.PretrainedConfig, transformers.PreTrainedTokenizer]:
#      83     """
#      84     Parses ONNX model from the `model_path` provided. It additionally
#      85     creates config and tokenizer objects from the `deployment path`,
#    (...)
#      93     :return: file path to the processed ONNX file for the engine to compile
#      94     """
# ---> 95     deployment_path, onnx_path = get_deployment_path(model_path, onnx_model_name)
#      97     hf_logger = logging.getLogger("transformers")
#      98     hf_logger_level = hf_logger.level
#
# File /opt/app-root/lib64/python3.9/site-packages/deepsparse/transformers/helpers.py:158, in get_deployment_path(model_path, onnx_model_name)
#     155     return model_path, os.path.join(model_path, onnx_model_name)
#     157 elif model_path.startswith("zoo:") or model_path.startswith("hf:"):
# --> 158     onnx_model_path = model_to_path(model_path)
#     159     return os.path.dirname(onnx_model_path), onnx_model_path.replace(
#     160         MODEL_ONNX_NAME, onnx_model_name
#     161     )
#     162 else:
#
# File /opt/app-root/lib64/python3.9/site-packages/deepsparse/utils/onnx.py:132, in model_to_path(model)
#     128     model = Model(model)
#     130 if Model is not object and isinstance(model, Model):
#     131     # trigger download and unzipping of deployment directory if not cached
# --> 132     model.deployment.path
#     134     # default to the main onnx file for the model
#     135     model = model.deployment.get_file(MODEL_ONNX_NAME).path
#
# File /opt/app-root/lib64/python3.9/site-packages/sparsezoo/objects/file.py:93, in File.path(self)
#      91         return expected_path
#      92     else:
# ---> 93         self.download()
#      95 elif not os.path.exists(self._path):
#      96     self.download()
#
# File /opt/app-root/lib64/python3.9/site-packages/sparsezoo/objects/directory.py:183, in Directory.download(self, destination_path, overwrite, retries, retry_sleep_sec)
#     181 for attempt in range(retries):
#     182     try:
# --> 183         download_file(
#     184             url_path=target_directory.url,
#     185             dest_path=new_file_path,
#     186             overwrite=overwrite,
#     187         )
#     189         target_directory._path = new_file_path
#     190         target_directory.unzip()
#
# File /opt/app-root/lib64/python3.9/site-packages/sparsezoo/utils/download.py:59, in download_file(url_path, dest_path, num_retries, **kwargs)
#      48 """
#      49 Download a file from the given url to the desired local path
#      50
#    (...)
#      54
#      55 """
#      56 downloader = Downloader(
#      57     url=url_path, download_path=dest_path, max_retries=num_retries
#      58 )
# ---> 59 downloader.download()
#
# File /opt/app-root/lib64/python3.9/site-packages/sparsezoo/utils/download.py:223, in Downloader.download(self, *args, **kwargs)
#     221 def download(self, *args, **kwargs) -> None:
#     222     self.queue_jobs(*args, **kwargs)
# --> 223     self.run()
#
# File /opt/app-root/lib64/python3.9/site-packages/sparsezoo/utils/download.py:307, in Downloader.run(self, num_threads)
#     304             futures.append(future)
#     306         for future in futures:
# --> 307             future.result()
#     308 is_prev_job_queue_success = True
#
# File /usr/lib64/python3.9/concurrent/futures/_base.py:637, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     636 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 637     self.shutdown(wait=True)
#     638     return False
#
# File /usr/lib64/python3.9/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File /usr/lib64/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib64/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/app-root/lib64/python3.9/site-packages/sparsezoo/utils/download.py", line 330, in execute_job_from_queue
#     job.func(**job.func_kwargs, **kwargs)
#   File "/opt/app-root/lib64/python3.9/site-packages/sparsezoo/utils/download.py", line 383, in download_file
#     f.write(chunk)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib64/python3.9/logging/__init__.py", line 1086, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/iostream.py", line 694, in write
#     self._schedule_flush()
#   File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/iostream.py", line 590, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/app-root/lib64/python3.9/site-packages/zmq/sugar/socket.py", line 620, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 746, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 787, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/usr/lib64/python3.9/threading.py", line 937, in _bootstrap
#     self._bootstrap_inner()
#   File "/usr/lib64/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/usr/lib64/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.9/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/usr/lib64/python3.9/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/opt/app-root/lib64/python3.9/site-packages/sparsezoo/utils/download.py", line 338, in execute_job_from_queue
#     _LOGGER.error(_err)
# Message: OSError(28, 'No space left on device')
# Arguments: ()
# [Errno 28] No space left on device
# [Errno 28] No space left on device

# %% [markdown]
# # Gather Data, Chunk it and Store it in the vector store
#
# If the database is not present, then create it by downloading and chunking the files.  If it is present, then just load it.

# %%
persist_dir = "db"

check_file = "False"

path = 'db/chroma.sqlite3'

check_file = os.path.isfile(path)

if check_file is False:
    urls = [
        r'https://access.redhat.com/documentation/en-us/red_hat_enterprise_linux/9/html-single/performing_a_standard_rhel_9_installation/index',
        r'https://access.redhat.com/documentation/en-us/red_hat_enterprise_linux/9/html-single/performing_an_advanced_rhel_9_installation/index',
        r'https://access.redhat.com/documentation/en-us/red_hat_enterprise_linux/9/html-single/configuring_basic_system_settings/index',
        r'https://access.redhat.com/documentation/en-us/red_hat_enterprise_linux/9/html-single/security_hardening/index',
        r'https://access.redhat.com/documentation/en-us/red_hat_enterprise_linux/9/html-single/composing_a_customized_rhel_system_image/index',
        r'https://access.redhat.com/documentation/en-us/red_hat_enterprise_linux/9/html-single/upgrading_from_rhel_8_to_rhel_9/index',
        r'https://www.redhat.com/en/resources/red-hat-enterprise-linux-subscription-guide'
    ]
    
    loader = WebBaseLoader(urls)
    
    docs = loader.load()
    
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1250, chunk_overlap=0)
    
    splits = text_splitter.split_documents(docs)
    
    vectorstore = Chroma.from_documents(documents=splits, embedding=embd, persist_directory="db")

else:
    
    vectorstore = Chroma(persist_directory=persist_dir, embedding_function=embd)
    
retriever = vectorstore.as_retriever()

# %% [markdown]
# # Run the RAG

# %%
from langchain_core.runnables import RunnableParallel
from typing import List
from langchain_core.documents import Document


# Prompt
rag_template = """
Given a question write an answer.
Use only the supplied source docs.
If you don't know the answer, just say that you don't know.  Do not fake the answer.
If the answer is relevant, then ALWAYS include a "SOURCES" part in your answer.

QUESTION: {question}
=========
{source_docs}
=========
ANSWER: 
"""

rag_prompt = ChatPromptTemplate.from_template(rag_template)

def format_docs(docs: List[Document]) -> str:
    return "\n\n".join(
        f"Content: {doc.page_content}\nSource: {doc.metadata['source']}" for doc in docs
    )

rag_chain_from_docs = (
    RunnablePassthrough.assign(
        source_docs=(lambda x: format_docs(x["source_docs"]))
    )
    | rag_prompt
    | model
    | StrOutputParser()
)

rag_chain = RunnableParallel(
    {
        "source_docs": retriever,
        "question": RunnablePassthrough()
    }
).assign(answer=rag_chain_from_docs)

question = "How does SELinux work?"

results = (rag_chain.invoke(question))
answer = results["answer"]
print(answer)
# Out:
#  SELinux (Security-Enhanced Linux) is a security extension for the Linux operating system that helps protect against unauthorized access to files, processes, and other resources. It uses a Mandatory Access Control (MAC) model, which sets strict access control rules that must be followed by the system and its applications.
#
# SELinux labels are used to identify different types of data and processes, and access control decisions are based on these labels. The labels define the security context for each resource, including the file type, process, or user. SELinux policies specify the allowed access between different security contexts.
#
# When a process attempts to access a resource, SELinux checks the security context of both the process and the resource against the policy rules. If the access is allowed, the operation is permitted; otherwise, it is denied. This helps prevent unauthorized access or modification of sensitive data.
#
# SELinux policies can be managed using various tools like `setsebool`, `sestatus`, and `audit2allow`. These tools allow administrators to modify policy rules based on specific use cases and audit logs.
#
# SOURCES:
# - [SELinux Homepage](https://www.redhat.com/en/technologies/security-services/selinux)
# - [Understanding SELinux Policies](https://access.redhat.com/documentation/en-US/Red_Hat_Enterprise_Linux/7/html/Security-Enhanced_Linux/ch-understanding_policies.html)
# - [SELinux Concepts and Terminology](https://access.redhat.com/documentation/en-US/Red_Hat_Enterprise_Linux/7/html/Security-Enhanced_Linux/concepts_glossary.html)
